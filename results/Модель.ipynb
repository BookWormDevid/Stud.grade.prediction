# %% [markdown]
# <a href="https://colab.research.google.com/github/BookWormDevid/Stud.grade.prediction/blob/main/%D0%9C%D0%BE%D0%B4%D0%B5%D0%BB%D1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.utils import shuffle
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
data = pd.read_csv('dataset.csv')
print(data.head(5))
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       2    0   18        2        2        2     4     4     1     5  ...
# 1       2    0   17        2        2        1     1     1     1     3  ...
# 2       2    0   15        2        1        1     1     1     1     3  ...
# 3       2    0   15        2        2        1     4     2     2     4  ...
# 4       2    0   16        2        2        1     3     3     3     3  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         4  11  11  11
# 1       5         3      3     1     1       3         2   9  11  11
# 2       4         3      2     2     3       3         6  12  13  12
# 3       3         2      2     1     1       5         0  14  14  14
# 4       4         3      2     1     2       5         0  11  13  13
#
# [5 rows x 33 columns]

# %%
dataset = pd.DataFrame(data)
dataset.head(5)
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       2    0   18        2        2        2     4     4     1     5  ...
# 1       2    0   17        2        2        1     1     1     1     3  ...
# 2       2    0   15        2        1        1     1     1     1     3  ...
# 3       2    0   15        2        2        1     4     2     2     4  ...
# 4       2    0   16        2        2        1     3     3     3     3  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         4  11  11  11
# 1       5         3      3     1     1       3         2   9  11  11
# 2       4         3      2     2     3       3         6  12  13  12
# 3       3         2      2     1     1       5         0  14  14  14
# 4       4         3      2     1     2       5         0  11  13  13
#
# [5 rows x 33 columns]

# %%
target = pd.DataFrame(dataset[["G1","G2","G3"]], columns=["G3"])
dataset = shuffle(dataset)
dataset.head(5)
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 167       2    0   17        2        2        1     4     4     3     5  ...
# 23        2    1   16        2        1        1     2     2     3     3  ...
# 619       1    0   18        2        2        1     3     3     4     4  ...
# 310       2    0   18        1        2        1     2     1     3     3  ...
# 483       1    0   16        1        2        1     2     2     3     3  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 167       4         2      1     1     1       4         0  13  13  13
# 23        5         4      4     2     4       5         2  10  10  10
# 619       4         3      2     1     3       3         6  13  12  13
# 310       4         3      5     1     2       3        12   8   9  10
# 483       3         4      5     1     2       1         1   9  10  11
#
# [5 rows x 33 columns]

# %%
features = dataset


x = np.array(features)
y = np.array(target)

x_min = np.min(x, axis=0)
x_max = np.max(x, axis=0)

x_normalized = (x - x_min) / (x_max - x_min)

y_min = np.min(y)
y_max = np.max(y)

y_normalized = (y - y_min) / (y_max - y_min)

# %%
train_size = int(0.8 * x_normalized.shape[0])

# Использовать комментирование для тонкой настройки нейронки и экспериментов

x_train, x_test = x_normalized[:train_size], x_normalized[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='leaky_relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='leaky_relu'),
    #tf.keras.layers.Dropout(0.001),
    tf.keras.layers.Dense(1, activation='relu')
])
model.summary()
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.01), loss="MSLE")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_146 (Dense)                    │ (None, 128)                 │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_76 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
model.fit(x_train, y_train, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3031 - val_loss: 0.1379
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0843 - val_loss: 0.1008
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1348 - val_loss: 0.0667
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0800 - val_loss: 0.4501
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1578 - val_loss: 0.0903
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1234 - val_loss: 0.0501
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0872 - val_loss: 0.0512
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0948 - val_loss: 0.1840
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1261 - val_loss: 0.1616
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0954 - val_loss: 0.0562
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0887 - val_loss: 0.0984
# Epoch 12/50
# ...

# %%
test_loss = model.evaluate(x_test, y_test)
print(f'Test loss (MSE): {test_loss}')
predictions = model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0793
# Test loss (MSE): 0.07345151901245117
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
predictions = model.predict(x_test)

avg_error = []

for i in range(100):
    print(f'Предсказанная оценка: {round(predictions[i][0] * 5):.2f}, Реальная оценка : {y_test[i][0] * 5}')
    avg_error.append(abs(predictions[i][0] * 5) - y_test[i][0] * 5)
    # Временно умножаем значения на 5, так как в португалии 20 бальная система оценки
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Предсказанная оценка: 57.00, Реальная оценка : 60
# Предсказанная оценка: 57.00, Реальная оценка : 40
# Предсказанная оценка: 68.00, Реальная оценка : 50
# Предсказанная оценка: 63.00, Реальная оценка : 40
# Предсказанная оценка: 64.00, Реальная оценка : 30
# Предсказанная оценка: 66.00, Реальная оценка : 40
# Предсказанная оценка: 62.00, Реальная оценка : 80
# Предсказанная оценка: 71.00, Реальная оценка : 70
# Предсказанная оценка: 62.00, Реальная оценка : 50
# Предсказанная оценка: 62.00, Реальная оценка : 45
# Предсказанная оценка: 72.00, Реальная оценка : 55
# Предсказанная оценка: 74.00, Реальная оценка : 45
# Предсказанная оценка: 62.00, Реальная оценка : 50
# Предсказанная оценка: 67.00, Реальная оценка : 40
# Предсказанная оценка: 63.00, Реальная оценка : 80
# Предсказанная оценка: 67.00, Реальная оценка : 60
# Предсказанная оценка: 62.00, Реальная оценка : 50
# Предсказанная оценка: 54.00, Реальная оценка : 70
# ...

# %%
#print(dataset.describe())
#print(dataset.isnull().sum())
#print(dataset[["G1","G2","G3"]].value_counts())
print(sum(avg_error)/len(avg_error))  # Это для проверки нейронки на неточность
# Out:
# 8.866970252990722
